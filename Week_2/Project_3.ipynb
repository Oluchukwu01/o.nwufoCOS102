# %%
from tabulate import tabulate
data = [["Evelyn",17,5.5,80],["Jessica",16,6.0,85],["Somto",17,5.4,70],["Edith",18,5.9,60]
         ,["Liza",16,5.6,76],["Madonna",18,5.5,66],["Waje",17,6.1,87],["Tola",20,6.0,95]
         ,["Aisha",19,5.5,80],["Latifa",17,5.6,49],["Chinedu",19,5.7,74],["Liam",16,5.9,87,]
        ,["Wale",18,5.8,75],["Gbenga",17,6.1,68],["Abiola",20,5.9,66],["Kola",19,5.5,66]
         ,["Kunle",16,6.1,87],["George",18,5.4,98],["Thomas",16,5.8,54],["Wesley",19,5.7,60]]
headers = ['Name','Age','Height','Scores']
print(tabulate(data, headers=headers,tablefmt='grid'))
# Out:
# +---------+-------+----------+----------+
# | Name    |   Age |   Height |   Scores |
# +=========+=======+==========+==========+
# | Evelyn  |    17 |      5.5 |       80 |
# +---------+-------+----------+----------+
# | Jessica |    16 |      6   |       85 |
# +---------+-------+----------+----------+
# | Somto   |    17 |      5.4 |       70 |
# +---------+-------+----------+----------+
# | Edith   |    18 |      5.9 |       60 |
# +---------+-------+----------+----------+
# | Liza    |    16 |      5.6 |       76 |
# +---------+-------+----------+----------+
# | Madonna |    18 |      5.5 |       66 |
# +---------+-------+----------+----------+
# | Waje    |    17 |      6.1 |       87 |
# +---------+-------+----------+----------+
# | Tola    |    20 |      6   |       95 |
# +---------+-------+----------+----------+
# | Aisha   |    19 |      5.5 |       80 |
# +---------+-------+----------+----------+
# | Latifa  |    17 |      5.6 |       49 |
# ...

# %% [markdown]
# ![diagram-export-14-03-2026-18_35_53.png](attachment:c1531fc9-56ec-4595-b62c-4e4458a5d3ed.png)
